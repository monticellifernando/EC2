# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### importamos los datos:

# %%
fondo = pd.read_csv( 'Fondo2.txt',decimal=',', header=0, names= ["canal_fondo","cuentas_fondo"], delim_whitespace=True )

hg = pd.read_csv( 'hg2.txt',decimal=',', header=0, names= ["canal_hg","cuentas_hg"], delim_whitespace=True )

sustrato = pd.read_csv( 'itosustrato.txt',decimal=',', header=0, names= ["canal_sustrato","cuentas_sustrato"], delim_whitespace=True )

ZnMnO = pd.read_csv( 'ZnMnO.txt',decimal=',', header=0, names= ["canal_ZnMnO","cuentas_ZnMnO"], delim_whitespace=True )

ZnMnO2 = pd.read_csv( 'ZnMnOrecocido.txt',decimal=',', header=0, names= ["canal_ZnMnO2","cuentas_ZnMnO2"], delim_whitespace=True )

# %% [markdown]
# ### ploteamos para ver la forma de los datos:

# %%
fondo.plot('canal_fondo','cuentas_fondo', title= "fondo")
hg.plot('canal_hg','cuentas_hg', title= "Hg")
sustrato.plot('canal_sustrato','cuentas_sustrato', title= "sustrato")
ZnMnO.plot('canal_ZnMnO','cuentas_ZnMnO', title= "ZnMnO")
ZnMnO2.plot('canal_ZnMnO2','cuentas_ZnMnO2', title= "ZnMnO2")
